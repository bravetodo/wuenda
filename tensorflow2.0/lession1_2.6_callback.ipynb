# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
class mycallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch , logs={}):
        if logs.get('loss') < 0.4:
            print('loss is low so cancelling training')
            self.model.stop_training = True

# %%
callback = mycallback()

# %%
(train_image, train_label),(test_image, test_label) = tf.keras.datasets.fashion_mnist.load_data()
# plt.plot(train_image[1])

# %%
train_image = train_image /255
test_image = test_image / 255

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.fit(train_image, train_label, epochs=10, callbacks=[callback])
# Out:
# Train on 60000 samples
# Epoch 1/10
# 59008/60000 [============================>.] - ETA: 0s - loss: 0.2353loss is low so cancelling training
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2352

# %%
model.evaluate(test_image, test_label)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.3324969881772995
